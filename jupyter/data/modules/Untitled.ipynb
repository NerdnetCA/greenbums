# %%
import numpy as np
import pandas as pd

tmp = pd.read_csv('frameshift_drive.csv')

dat = pd.read_json(tmp.to_json())
dat
# Out:
#     class grade   mass  integrity  power_draw  opt_mass  max_fuel      cost
# 0       2     E    2.5         46        0.16        48       0.6      1978
# 1       2     D    1.0         41        0.18        54       0.6      5934
# 2       2     C    2.5         51        0.20        60       0.6     17803
# 3       2     B    4.0         61        0.25        75       0.8     53408
# 4       2     A    2.5         56        0.30        90       0.9    160224
# 5       3     E    5.0         58        0.24        80       1.2      6271
# 6       3     D    2.0         51        0.27        90       1.2     18812
# 7       3     C    5.0         64        0.30       100       1.2     56435
# 8       3     B    8.0         77        0.38       125       1.5    169304
# 9       3     A    5.0         70        0.45       150       1.8    507912
# 10      4     E   10.0         72        0.24       280       2.0     19878
# ...
