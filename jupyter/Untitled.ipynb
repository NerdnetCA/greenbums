# %%
import numpy as np
import pandas as pd

# Read in some of the data files
footydata = pd.read_json('data/footydata.json')
ships = pd.read_json('data/ships.json')
footyitems = pd.read_json('data/footyitems.json')

shipmats_data = pd.read_json("data/matsdata.json")

# Sort the ship data by manufacturer, and sort by mass within manufacturer
ships_by_manumass = ships.sort_values(["manufacturer","mass"])

# Show the Footy Data table
shipmats_data.sort_values(['subtype','grade'])
# Out:
#                                    name           subtype        grade  \
# 42           Unidentified Scan Archives     Data archives       Common
# 13                  Divergent Scan Data     Data archives         Rare
# 7             Classified Scan Databanks     Data archives     Standard
# 3              Anomalous Bulk Scan Data     Data archives  Very common
# 8              Classified Scan Fragment     Data archives    Very rare
# 20              Irregular Emission Data     Emission data       Common
# 11                Decoded Emission Data     Emission data         Rare
# 41             Unexpected Emission Data     Emission data     Standard
# 15  Exceptional Scrambled Emission Data     Emission data  Very common
# 1       Abnormal Compact Emissions Data     Emission data    Very rare
# 21           Modified Consumer Firmware  Encoded firmware       Common
# 30              Security Firmware Patch  Encoded firmware         Rare
# ...

# %%
# Set option to display all rows
pd.set_option('display.max_rows', None)
