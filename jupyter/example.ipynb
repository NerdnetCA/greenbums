# %%
import numpy as np
import pandas as pd

# Read in some of the data files
footydata = pd.read_json('data/footydata.json')
ships = pd.read_json('data/ships.json')
footyitems = pd.read_json('data/footyitems.json')

# Sort the ship data by manufacturer, and sort by mass within manufacturer
ships_by_manumass = ships.sort_values(["manufacturer","mass"])

# Show the Footy Data table
footydata
# Out:
#                                   name  \
# 0                        Accident Logs
# 1                  Air Quality Reports
# 2                     Atmospheric Data
# 3                           Audio Logs
# 4                       AX Combat Logs
# 5                      Ballistics Data
# 6               Biological Weapon Data
# 7                       Biometric Data
# 8                       Blacklist Data
# 9                   Blood Test Results
# 10                      Campaign Plans
# 11                           Cat Media
# 12                         Census Data
# 13            Chemical Experiment Data
# 14                   Chemical Formulae
# 15                  Chemical Inventory
# 16                    Chemical Patents
# 17                Chemical Weapon Data
# 18               Classic Entertainment
# 19              Clinical Trial Records
# 20                    Cocktail Recipes
# 21            Combat Training Material
# 22               Combatant Performance
# 23                    Conflict History
# 24                    Criminal Records
# 25                 Crop Yield Analysis
# 26                    Culinary Recipes
# 27                     Digital Designs
# 28                           Duty Rota
# 29                  Employee Directory
# 30                   Employee Expenses
# 31               Employee Genetic Data
# 32                  Employment History
# 33   Enhanced Interrogation Recordings
# 34                  Espionage Material
# 35                Evacuation Protocols
# 36                Exploration Journals
# 37               Extraction Yield Data
# 38                  Faction Associates
# 39                Faction Donator List
# 40                        Faction News
# 41               Financial Projections
# 42                      Fleet Registry
# 43                Gene Sequencing Data
# 44                    Genetic Research
# 45                     Geological Data
# 46                     Hydroponic Data
# 47                       Incident Logs
# 48               Influence Projections
# 49             Internal Correspondence
# 50            Interrogation Recordings
# 51                Interview Recordings
# 52                    Job Applications
# 53                           Kompromat
# 54                    Literary Fiction
# 55                    Maintenance Logs
# 56          Manufacturing Instructions
# 57                     Medical Records
# 58                     Meeting Minutes
# 59                      Mineral Survey
# 60                    Mining Analytics
# 61            Multimedia Entertainment
# 62              Network Access History
# 63          Network Security Protocols
# 64                 Next of Kin Records
# 65                            NOC Data
# 66                  Operational Manual
# 67                       Opinion Polls
# 68                     Patient History
# 69                       Patrol Routes
# 70                 Payroll Information
# 71                       Personal Logs
# 72              Pharmaceutical Patents
# 73                        Photo Albums
# 74                 Plant Growth Charts
# 75              Political Affiliations
# 76                       Prisoner Logs
# 77                  Production Reports
# 78                 Production Schedule
# 79                          Propaganda
# 80                    Purchase Records
# 81                   Purchase Requests
# 82                  Radioactivity Data
# 83               Reactor Output Review
# 84                      Recycling Logs
# 85               Residential Directory
# 86                    Risk Assessments
# 87                       Sales Records
# 88                   Security Expenses
# 89                     Seed Geneaology
# 90            Settlement Assault Plans
# 91            Settlement Defence Plans
# 92             Shareholder Information
# 93                     Slush Fund Logs
# 94                Smear Campaign Plans
# 95              Spectral Analysis Data
# 96                             Spyware
# 97               Stellar Activity Logs
# 98                   Surveillance Logs
# 99                      Tactical Plans
# 100                        Tax Records
# 101              Topographical Surveys
# 102                     Travel Permits
# 103           Troop Deployment Records
# 104                   Union Membership
# 105                Vaccination Records
# 106                   Vaccine Research
# 107                VIP Security Detail
# 108                      Virology Data
# 109                              Virus
# 110                   Visitor Register
# 111                   Weapon Inventory
# 112                   Weapon Test Data
# 113             Xeno-Defence Protocols
#
#                                     locations
# 0             [RES, PWR, IND, HAB, EXT, AGRI]
# 1    [STO, PWR, IND, HAB, EXT, AGRI, MISSION]
# 2            [IMARK, RES, IND, CSAT, MISSION]
# 3                        [CMD, SETT, MISSION]
# 4                                       [CMD]
# 5                       [IMARK, CMD, MISSION]
# 6                                          []
# 7                         [MED, CMD, MISSION]
# 8                                 [CMD, CSAT]
# 9                         [MED, CMD, MISSION]
# 10                                      [HAB]
# 11                                      [HAB]
# 12                                      [HAB]
# 13                  [RES, IND, AGRI, MISSION]
# 14                  [RES, IND, AGRI, MISSION]
# 15             [RES, IND, EXT, AGRI, MISSION]
# 16                  [RES, IND, AGRI, MISSION]
# 17                                         []
# 18                                      [HAB]
# 19                        [MED, RES, MISSION]
# 20                                      [HAB]
# 21                   [RES, HAB, CMD, MISSION]
# 22                        [HAB, CMD, MISSION]
# 23                                      [CMD]
# 24                                      [CMD]
# 25                                     [AGRI]
# 26                                      [HAB]
# 27                             [HAB, MISSION]
# 28                       [RES, PWR, IND, CMD]
# 29                                      [HAB]
# 30                                      [HAB]
# 31                                 [RES, CMD]
# 32                                      [HAB]
# 33                                      [CMD]
# 34                                         []
# 35                   [PWR, IND, HAB, MISSION]
# 36                                      [HAB]
# 37                   [RES, IND, EXT, MISSION]
# 38                                      [HAB]
# 39                                      [HAB]
# 40                                [HAB, CSAT]
# 41                                      [HAB]
# 42                                         []
# 43                  [MED, RES, AGRI, MISSION]
# 44                  [MED, RES, AGRI, MISSION]
# 45                                      [EXT]
# 46                                     [AGRI]
# 47                                      [CMD]
# 48                                      [HAB]
# 49                                [HAB, CSAT]
# 50                                      [CMD]
# 51                                         []
# 52                                 [HAB, CMD]
# 53                                         []
# 54                                      [HAB]
# 55                [IMARK, PWR, AGRI, MISSION]
# 56        [STO, RES, IND, HAB, CSAT, MISSION]
# 57                        [MED, RES, MISSION]
# 58                                      [HAB]
# 59                   [IND, EXT, CSAT, MISION]
# 60                        [IND, EXT, MISSION]
# 61                                      [HAB]
# 62                                      [HAB]
# 63                                         []
# 64                                      [HAB]
# 65                            [CSAT, MISSION]
# 66        [MED, RES, IND, CMD, CSAT, MISSION]
# 67                                 [HAB, CMD]
# 68                                      [MED]
# 69                      [IMARK, CMD, MISSION]
# 70                                      [HAB]
# 71                                      [HAB]
# 72             [MED, RES, CMD, AGRI, MISSION]
# 73                                      [HAB]
# 74                                     [AGRI]
# 75                                      [HAB]
# 76                                         []
# 77                  [RES, IND, AGRI, MISSION]
# 78                  [RES, IND, AGRI, MISSION]
# 79                                     [CSAT]
# 80                                [HAB, AGRI]
# 81                                     [AGRI]
# 82             [RES, PWR, IND, CSAT, MISSION]
# 83             [RES, PWR, IND, CSAT, MISSION]
# 84                        [IND, HAB, MISSION]
# 85                                      [HAB]
# 86                        [RES, HAB, MISSION]
# 87                                      [HAB]
# 88                             [CMD, MISSION]
# 89                                [RES, AGRI]
# 90                             [CMD, MISSION]
# 91                               [IMARK, CMD]
# 92                                         []
# 93                                         []
# 94                                 [HAB, CMD]
# 95                  [RES, CMD, CSAT, MISSION]
# 96                                         []
# 97            [RES, CMD, AGRI, CSAT, MISSION]
# 98                       [CMD, CSAT, MISSION]
# 99                      [IMARK, CMD, MISSION]
# 100                                     [HAB]
# 101                 [RES, IND, CSAT, MISSION]
# 102                                     [HAB]
# 103                            [CMD, MISSION]
# 104                                     [PWR]
# 105                                     [RES]
# 106                                        []
# 107                                        []
# 108                                     [RES]
# 109                                        []
# 110                                     [HAB]
# 111                            [CMD, MISSION]
# 112                            [CMD, MISSION]
# 113                                        []
