# %%
import numpy as np
import pandas as pd

engineers = pd.read_csv('data/engineers.csv')

engineers
# Out:
#                 Name             System                             Invite  \
# 0      Bitch-Ass Tod            Wolf397            earn 15 bounty vouchers
# 1        Bill Turner             Alioth             friendly with Alliance
# 2     Elvira Martuuk               Khun                       travel 300ly
# 3        The Dweller               Wyrd            deal in 5 black markets
# 4   Felicity Farseer             Deciat             exploration rank Scout
# 5          Liz Ryder            Eyrybia   friendly with Eurybia Blue Mafia
# 6        Mel Brandon          Luchtaine    invitation from Colonia Council
# 7       Marsha Hicks                Tir          exploration rank Surveyor
# 8       Juri Ishmaak             Giryak                    50 combat bonds
# 9     Petra Olmanova              Asura                 combat rank Expert
# 10      Etienne Dorn                Los                  trade rank Dealer
# ...

# %%
ships = pd.read_json('data/ships.json')

ships.sort_values(["manufacturer","mass"])
# Out:
#                     name     manufacturer  speed  boost  shield  agility  \
# 1                  Eagle    Core Dynamics    240    350      60      178
# 12               Vulture    Core Dynamics    210    340     240      162
# 22  Federal Assault Ship    Core Dynamics    210    350     200      139
# 21      Federal Dropship    Core Dynamics    180    300     200      114
# 23       Federal Gunship    Core Dynamics    170    280     250      118
# 24      Federal Corvette    Core Dynamics    200    260     555      105
# 0             Sidewinder   Faulcon deLacy    220    320      40      160
# 5            Viper MkIII   Faulcon deLacy    320    400     105      135
# 7            Cobra MkIII   Faulcon deLacy    280    400      80      140
# 6             Viper MkIV   Faulcon deLacy    270    340     150      127
# 31         Krait Phantom   Faulcon deLacy    250    350     200      126
# 32            Krait MkII   Faulcon deLacy    240    330     220      126
# ...
